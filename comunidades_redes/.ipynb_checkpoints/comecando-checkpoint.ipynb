# %%
import networkx as nx
import numpy as np 
import matplotlib.pyplot as plt
import csv

# %%
with open('data/rede1_duas_comunidades.csv') as f:

# %%
G = nx.read_adjlist('data/rede1_duas_comunidades.csv')

# %%
nx.draw(G)
